# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow import keras
from keras import layers
from keras.models import Sequential
from keras.layers import Dense,Dropout
from kerastuner.tuners import RandomSearch
from kerastuner.engine.hyperparameters import HyperParameters

# %%
conda install -c conda-forge tensorflow
# Out:
# Retrieving notices: ...working... done
# Channels:
#  - conda-forge
#  - defaults
# Platform: linux-64
# Collecting package metadata (repodata.json): done
# Solving environment: | warning  libmamba Added empty dependency for problem type SOLVER_RULE_UPDATE
# done
#
# ## Package Plan ##
#
#   environment location: /home/j_choi9/miniconda3/envs/py3
#
#   added / updated specs:
#     - tensorflow
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     absl-py-2.1.0              |     pyhd8ed1ab_0         105 KB  conda-forge
#     astunparse-1.6.3           |     pyhd8ed1ab_0          15 KB  conda-forge
#     c-ares-1.32.2              |       h4bc722e_0         176 KB  conda-forge
#     cached-property-1.5.2      |       hd8ed1ab_1           4 KB  conda-forge
#     cached_property-1.5.2      |     pyha770c72_1          11 KB  conda-forge
#     cuda-crt-tools-12.5.82     |       ha770c72_0          26 KB  conda-forge
#     cuda-cudart-12.5.82        |       he02047a_0          22 KB  conda-forge
#     cuda-cudart_linux-64-12.5.82|       h85509e4_0         184 KB  conda-forge
#     cuda-nvcc-tools-12.5.82    |       hd3aeb46_0        22.7 MB  conda-forge
#     cuda-nvrtc-12.5.82         |       he02047a_0        18.1 MB  conda-forge
#     cuda-nvtx-12.5.82          |       he02047a_0          31 KB  conda-forge
#     cuda-nvvm-tools-12.5.82    |       h59595ed_0        11.2 MB  conda-forge
#     cuda-version-12.5          |       hd4f0392_3          21 KB  conda-forge
#     cyrus-sasl-2.1.27          |       h54b06d7_7         214 KB  conda-forge
#     flatbuffers-24.3.25        |       h59595ed_0         1.4 MB  conda-forge
#     font-ttf-dejavu-sans-mono-2.37|       hab24e00_0         388 KB  conda-forge
#     font-ttf-inconsolata-3.000 |       h77eed37_0          94 KB  conda-forge
#     font-ttf-source-code-pro-2.038|       h77eed37_0         684 KB  conda-forge
#     font-ttf-ubuntu-0.83       |       h77eed37_2         1.5 MB  conda-forge
#     fonts-conda-ecosystem-1    |                0           4 KB  conda-forge
#     fonts-conda-forge-1        |                0           4 KB  conda-forge
#     gast-0.5.5                 |     pyhd8ed1ab_0          23 KB  conda-forge
#     giflib-5.2.2               |       hd590300_0          75 KB  conda-forge
#     google-pasta-0.2.0         |     pyh8c360ce_0          42 KB  conda-forge
#     graphite2-1.3.13           |    h59595ed_1003          95 KB  conda-forge
#     grpcio-1.62.2              |  py312hb06c811_0        1022 KB  conda-forge
#     h5py-3.11.0                |nompi_py312hb7ab980_102         1.2 MB  conda-forge
#     harfbuzz-9.0.0             |       hfac3d4d_0         1.5 MB  conda-forge
#     hdf5-1.14.3                |nompi_hdf9ad27_105         3.7 MB  conda-forge
#     keras-3.4.1                |     pyhd8ed1ab_2         849 KB  conda-forge
#     lame-3.100                 |    h166bdaf_1003         496 KB  conda-forge
#     lcms2-2.16                 |       hb7c19ff_0         239 KB  conda-forge
#     lerc-4.0.0                 |       h27087fc_0         275 KB  conda-forge
#     libabseil-20240116.2       | cxx17_he02047a_1         1.2 MB  conda-forge
#     libaec-1.1.3               |       h59595ed_0          35 KB  conda-forge
#     libclang-18.1.8            |default_hf981a13_1          23 KB  conda-forge
#     libclang13-18.1.8          |default_h9def88c_1        10.5 MB  conda-forge
#     libcublas-12.5.3.2         |       he02047a_0       240.0 MB  conda-forge
#     libcufft-11.2.3.61         |       he02047a_0       148.6 MB  conda-forge
#     libcurand-10.3.6.82        |       he02047a_0        39.8 MB  conda-forge
#     libcurl-8.8.0              |       hca28451_1         401 KB  conda-forge
#     libcusolver-11.6.3.83      |       he02047a_0        79.3 MB  conda-forge
#     libcusparse-12.5.1.3       |       he02047a_0       119.1 MB  conda-forge
#     libdeflate-1.20            |       hd590300_0          70 KB  conda-forge
#     libev-4.33                 |       hd590300_2         110 KB  conda-forge
#     libevent-2.1.12            |       hf998b51_1         417 KB  conda-forge
#     libgcrypt-1.11.0           |       h4ab18f5_1         668 KB  conda-forge
#     libgrpc-1.62.2             |       h15f2491_0         7.0 MB  conda-forge
#     libjpeg-turbo-3.0.0        |       hd590300_1         604 KB  conda-forge
#     libllvm18-18.1.8           |       h8b73ec9_1        36.5 MB  conda-forge
#     libnghttp2-1.58.0          |       h47da74e_1         617 KB  conda-forge
#     libntlm-1.4                |    h7f98852_1002          32 KB  conda-forge
#     libnvjitlink-12.5.82       |       he02047a_0        15.9 MB  conda-forge
#     libogg-1.3.5               |       h4ab18f5_0         201 KB  conda-forge
#     libopus-1.3.1              |       h7f98852_1         255 KB  conda-forge
#     libre2-11-2023.09.01       |       h5a48ba9_2         227 KB  conda-forge
#     libssh2-1.11.0             |       h0841786_0         265 KB  conda-forge
#     libtiff-4.6.0              |       h1dd3fc0_3         276 KB  conda-forge
#     libvorbis-1.3.7            |       h9c3ff4c_0         280 KB  conda-forge
#     libwebp-base-1.4.0         |       hd590300_0         429 KB  conda-forge
#     libxml2-2.12.7             |       h4c95cb1_3         689 KB  conda-forge
#     markdown-3.6               |     pyhd8ed1ab_0          76 KB  conda-forge
#     markdown-it-py-3.0.0       |     pyhd8ed1ab_0          63 KB  conda-forge
#     mdurl-0.1.2                |     pyhd8ed1ab_0          14 KB  conda-forge
#     ml_dtypes-0.3.2            |  py312hfb8ada1_0         168 KB  conda-forge
#     mysql-8.3.0                |       h27aab58_4         339 KB  conda-forge
#     mysql-client-8.3.0         |       h545f5f4_4         4.3 MB  conda-forge
#     mysql-devel-8.3.0          |       hf1915f5_4         1.8 MB  conda-forge
#     mysql-server-8.3.0         |       h27b9c54_4        17.2 MB  conda-forge
#     namex-0.0.8                |     pyhd8ed1ab_0          11 KB  conda-forge
#     nccl-2.22.3.1              |       hbc370b7_0       107.3 MB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     openjpeg-2.5.2             |       h488ebb8_0         334 KB  conda-forge
#     opt_einsum-3.3.0           |     pyhc1e730c_2          57 KB  conda-forge
#     optree-0.12.1              |  py312h3402730_0         303 KB  conda-forge
#     pillow-10.4.0              |  py312h287a98d_0        40.1 MB  conda-forge
#     protobuf-4.25.3            |  py312h72fbbdf_0         382 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     python-flatbuffers-24.3.25 |     pyh59ac667_0          34 KB  conda-forge
#     qt-main-5.15.8             |      h320f8da_24        57.6 MB  conda-forge
#     re2-2023.09.01             |       h7f4b329_2          26 KB  conda-forge
#     rich-13.7.1                |     pyhd8ed1ab_0         180 KB  conda-forge
#     snappy-1.2.1               |       ha2e4443_0          41 KB  conda-forge
#     sqlite-3.32.3              |       hcee41ef_1         1.4 MB  conda-forge
#     tensorboard-2.16.2         |     pyhd8ed1ab_0         4.9 MB  conda-forge
#     tensorboard-data-server-0.7.0|  py312h241aef2_1         4.5 MB  conda-forge
#     tensorflow-2.16.2          |cuda120py312h02ad488_0          41 KB  conda-forge
#     tensorflow-base-2.16.2     |cuda120py312h7059624_0       348.6 MB  conda-forge
#     tensorflow-estimator-2.16.2|cuda120py312hfa0f5ef_0         682 KB  conda-forge
#     termcolor-2.4.0            |     pyhd8ed1ab_0          12 KB  conda-forge
#     werkzeug-3.0.3             |     pyhd8ed1ab_0         237 KB  conda-forge
#     wrapt-1.16.0               |  py312h98912ed_0          61 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.33 GB
#
# The following NEW packages will be INSTALLED:
#
#   absl-py            conda-forge/noarch::absl-py-2.1.0-pyhd8ed1ab_0
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.12-h4ab18f5_0
#   astunparse         conda-forge/noarch::astunparse-1.6.3-pyhd8ed1ab_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   c-ares             conda-forge/linux-64::c-ares-1.32.2-h4bc722e_0
#   cached-property    conda-forge/noarch::cached-property-1.5.2-hd8ed1ab_1
#   cached_property    conda-forge/noarch::cached_property-1.5.2-pyha770c72_1
#   cairo              conda-forge/linux-64::cairo-1.18.0-hbb29018_2
#   cuda-crt-tools     conda-forge/linux-64::cuda-crt-tools-12.5.82-ha770c72_0
#   cuda-cudart        conda-forge/linux-64::cuda-cudart-12.5.82-he02047a_0
#   cuda-cudart_linux~ conda-forge/noarch::cuda-cudart_linux-64-12.5.82-h85509e4_0
#   cuda-nvcc-tools    conda-forge/linux-64::cuda-nvcc-tools-12.5.82-hd3aeb46_0
#   cuda-nvrtc         conda-forge/linux-64::cuda-nvrtc-12.5.82-he02047a_0
#   cuda-nvtx          conda-forge/linux-64::cuda-nvtx-12.5.82-he02047a_0
#   cuda-nvvm-tools    conda-forge/linux-64::cuda-nvvm-tools-12.5.82-h59595ed_0
#   cuda-version       conda-forge/noarch::cuda-version-12.5-hd4f0392_3
#   cudnn              conda-forge/linux-64::cudnn-8.9.7.29-h092f7fd_3
#   flatbuffers        conda-forge/linux-64::flatbuffers-24.3.25-h59595ed_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_2
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   gast               conda-forge/noarch::gast-0.5.5-pyhd8ed1ab_0
#   gettext            conda-forge/linux-64::gettext-0.22.5-h59595ed_2
#   gettext-tools      conda-forge/linux-64::gettext-tools-0.22.5-h59595ed_2
#   giflib             conda-forge/linux-64::giflib-5.2.2-hd590300_0
#   google-pasta       conda-forge/noarch::google-pasta-0.2.0-pyh8c360ce_0
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h59595ed_1003
#   grpcio             conda-forge/linux-64::grpcio-1.62.2-py312hb06c811_0
#   h5py               conda-forge/linux-64::h5py-3.11.0-nompi_py312hb7ab980_102
#   harfbuzz           conda-forge/linux-64::harfbuzz-9.0.0-hfac3d4d_0
#   hdf5               conda-forge/linux-64::hdf5-1.14.3-nompi_hdf9ad27_105
#   keras              conda-forge/noarch::keras-3.4.1-pyhd8ed1ab_2
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   libabseil          conda-forge/linux-64::libabseil-20240116.2-cxx17_he02047a_1
#   libaec             conda-forge/linux-64::libaec-1.1.3-h59595ed_0
#   libasprintf        conda-forge/linux-64::libasprintf-0.22.5-h661eb56_2
#   libasprintf-devel  conda-forge/linux-64::libasprintf-devel-0.22.5-h661eb56_2
#   libcap             conda-forge/linux-64::libcap-2.69-h0f662aa_0
#   libclang-cpp15     conda-forge/linux-64::libclang-cpp15-15.0.7-default_h127d8a8_5
#   libcublas          conda-forge/linux-64::libcublas-12.5.3.2-he02047a_0
#   libcufft           conda-forge/linux-64::libcufft-11.2.3.61-he02047a_0
#   libcurand          conda-forge/linux-64::libcurand-10.3.6.82-he02047a_0
#   libcurl            conda-forge/linux-64::libcurl-8.8.0-hca28451_1
#   libcusolver        conda-forge/linux-64::libcusolver-11.6.3.83-he02047a_0
#   libcusparse        conda-forge/linux-64::libcusparse-12.5.1.3-he02047a_0
#   libev              conda-forge/linux-64::libev-4.33-hd590300_2
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libgcrypt          conda-forge/linux-64::libgcrypt-1.11.0-h4ab18f5_1
#   libgettextpo       conda-forge/linux-64::libgettextpo-0.22.5-h59595ed_2
#   libgettextpo-devel conda-forge/linux-64::libgettextpo-devel-0.22.5-h59595ed_2
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.50-h4f305b6_0
#   libgrpc            conda-forge/linux-64::libgrpc-1.62.2-h15f2491_0
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   libllvm15          conda-forge/linux-64::libllvm15-15.0.7-hb3ce162_4
#   libllvm18          conda-forge/linux-64::libllvm18-18.1.8-h8b73ec9_1
#   libnghttp2         conda-forge/linux-64::libnghttp2-1.58.0-h47da74e_1
#   libntlm            conda-forge/linux-64::libntlm-1.4-h7f98852_1002
#   libnvjitlink       conda-forge/linux-64::libnvjitlink-12.5.82-he02047a_0
#   libogg             conda-forge/linux-64::libogg-1.3.5-h4ab18f5_0
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-4.25.3-h08a7969_0
#   libre2-11          conda-forge/linux-64::libre2-11-2023.09.01-h5a48ba9_2
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libssh2            conda-forge/linux-64::libssh2-1.11.0-h0841786_0
#   libsystemd0        conda-forge/linux-64::libsystemd0-255-h3516f8a_1
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   markdown           conda-forge/noarch::markdown-3.6-pyhd8ed1ab_0
#   markdown-it-py     conda-forge/noarch::markdown-it-py-3.0.0-pyhd8ed1ab_0
#   mdurl              conda-forge/noarch::mdurl-0.1.2-pyhd8ed1ab_0
#   ml_dtypes          conda-forge/linux-64::ml_dtypes-0.3.2-py312hfb8ada1_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.6-h59595ed_0
#   mysql-client       conda-forge/linux-64::mysql-client-8.3.0-h545f5f4_4
#   mysql-common       conda-forge/linux-64::mysql-common-8.3.0-hf1915f5_4
#   mysql-devel        conda-forge/linux-64::mysql-devel-8.3.0-hf1915f5_4
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.3.0-hca2cd23_4
#   mysql-server       conda-forge/linux-64::mysql-server-8.3.0-h27b9c54_4
#   namex              conda-forge/noarch::namex-0.0.8-pyhd8ed1ab_0
#   nccl               conda-forge/linux-64::nccl-2.22.3.1-hbc370b7_0
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.102-h593d115_0
#   opt_einsum         conda-forge/noarch::opt_einsum-3.3.0-pyhc1e730c_2
#   optree             conda-forge/linux-64::optree-0.12.1-py312h3402730_0
#   pixman             conda-forge/linux-64::pixman-0.43.2-h59595ed_0
#   protobuf           conda-forge/linux-64::protobuf-4.25.3-py312h72fbbdf_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hb77b528_0
#   python-flatbuffers conda-forge/noarch::python-flatbuffers-24.3.25-pyh59ac667_0
#   re2                conda-forge/linux-64::re2-2023.09.01-h7f4b329_2
#   rich               conda-forge/noarch::rich-13.7.1-pyhd8ed1ab_0
#   snappy             conda-forge/linux-64::snappy-1.2.1-ha2e4443_0
#   tensorboard        conda-forge/noarch::tensorboard-2.16.2-pyhd8ed1ab_0
#   tensorboard-data-~ conda-forge/linux-64::tensorboard-data-server-0.7.0-py312h241aef2_1
#   tensorflow         conda-forge/linux-64::tensorflow-2.16.2-cuda120py312h02ad488_0
#   tensorflow-base    conda-forge/linux-64::tensorflow-base-2.16.2-cuda120py312h7059624_0
#   tensorflow-estima~ conda-forge/linux-64::tensorflow-estimator-2.16.2-cuda120py312hfa0f5ef_0
#   termcolor          conda-forge/noarch::termcolor-2.4.0-pyhd8ed1ab_0
#   werkzeug           conda-forge/noarch::werkzeug-3.0.3-pyhd8ed1ab_0
#   wrapt              conda-forge/linux-64::wrapt-1.16.0-py312h98912ed_0
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.1-hb711507_2
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-hb711507_2
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.1-hb711507_0
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.10-hb711507_0
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.2-hb711507_0
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.42-h4ab18f5_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.9-hb711507_1
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xf86vidmodep~ conda-forge/linux-64::xorg-xf86vidmodeproto-2.3.1-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#
# The following packages will be REMOVED:
#
#   jpeg-9e-h5eee18b_1
#
# The following packages will be UPDATED:
#
#   freetype            pkgs/main::freetype-2.12.1-h4a9f257_0 --> conda-forge::freetype-2.12.1-h267a509_2
#   glib                    pkgs/main::glib-2.78.4-h6a678d5_0 --> conda-forge::glib-2.80.3-h8a4344b_1
#   glib-tools         pkgs/main::glib-tools-2.78.4-h6a678d5~ --> conda-forge::glib-tools-2.80.3-h73ef956_1
#   gst-plugins-base   pkgs/main::gst-plugins-base-1.14.1-h6~ --> conda-forge::gst-plugins-base-1.24.5-hbaaba92_0
#   gstreamer          pkgs/main::gstreamer-1.14.1-h5eee18b_1 --> conda-forge::gstreamer-1.24.5-haf2f30d_0
#   icu                        pkgs/main::icu-73.1-h6a678d5_0 --> conda-forge::icu-73.2-h59595ed_0
#   krb5                    pkgs/main::krb5-1.20.1-h143b758_1 --> conda-forge::krb5-1.21.3-h659f571_0
#   lcms2                    pkgs/main::lcms2-2.12-h3be6417_0 --> conda-forge::lcms2-2.16-hb7c19ff_0
#   lerc                       pkgs/main::lerc-3.0-h295c915_0 --> conda-forge::lerc-4.0.0-h27087fc_0
#   libclang           pkgs/main::libclang-14.0.6-default_hc~ --> conda-forge::libclang-18.1.8-default_hf981a13_1
#   libclang13         pkgs/main::libclang13-14.0.6-default_~ --> conda-forge::libclang13-18.1.8-default_h9def88c_1
#   libdeflate          pkgs/main::libdeflate-1.17-h5eee18b_1 --> conda-forge::libdeflate-1.20-hd590300_0
#   libgfortran-ng     pkgs/main::libgfortran-ng-11.2.0-h003~ --> conda-forge::libgfortran-ng-14.1.0-h69a702a_0
#   libgfortran5       pkgs/main::libgfortran5-11.2.0-h12345~ --> conda-forge::libgfortran5-14.1.0-hc5f4f2c_0
#   libglib              pkgs/main::libglib-2.78.4-hdc74915_0 --> conda-forge::libglib-2.80.3-h8a4344b_1
#   libiconv              pkgs/main::libiconv-1.16-h5eee18b_3 --> conda-forge::libiconv-1.17-hd590300_2
#   libllvm14          pkgs/main::libllvm14-14.0.6-hdb19cb5_3 --> conda-forge::libllvm14-14.0.6-hcd5def8_4
#   libpng                pkgs/main::libpng-1.6.39-h5eee18b_0 --> conda-forge::libpng-1.6.43-h2797004_0
#   libpq                   pkgs/main::libpq-12.17-hdbd6064_0 --> conda-forge::libpq-16.3-ha72fbe1_0
#   libtiff               pkgs/main::libtiff-4.5.1-h6a678d5_0 --> conda-forge::libtiff-4.6.0-h1dd3fc0_3
#   libwebp-base       pkgs/main::libwebp-base-1.3.2-h5eee18~ --> conda-forge::libwebp-base-1.4.0-hd590300_0
#   libxcb                  pkgs/main::libxcb-1.15-h7f8727e_0 --> conda-forge::libxcb-1.16-hd590300_0
#   libxkbcommon       pkgs/main::libxkbcommon-1.0.1-h5eee18~ --> conda-forge::libxkbcommon-1.7.0-h2c5496b_1
#   libxml2              pkgs/main::libxml2-2.10.4-hfdd30dd_2 --> conda-forge::libxml2-2.12.7-h4c95cb1_3
#   libzlib                                 1.2.13-h4ab18f5_6 --> 1.3.1-h4ab18f5_1
#   mysql                  pkgs/main::mysql-5.7.24-h721c034_2 --> conda-forge::mysql-8.3.0-h27aab58_4
#   openjpeg             pkgs/main::openjpeg-2.4.0-h9ca470c_2 --> conda-forge::openjpeg-2.5.2-h488ebb8_0
#   pcre2                   pkgs/main::pcre2-10.42-hebb0a14_1 --> conda-forge::pcre2-10.44-h0f59acf_0
#   pillow             pkgs/main::pillow-10.3.0-py312h5eee18~ --> conda-forge::pillow-10.4.0-py312h287a98d_0
#   qt-main             pkgs/main::qt-main-5.15.2-h53bd1ea_10 --> conda-forge::qt-main-5.15.8-h320f8da_24
#   zlib                                    1.2.13-h4ab18f5_6 --> 1.3.1-h4ab18f5_1
#   zstd                     pkgs/main::zstd-1.5.5-hc292b87_2 --> conda-forge::zstd-1.5.6-ha6fb4c9_0
#
# The following packages will be SUPERSEDED by a higher-priority channel:
#
#   cyrus-sasl         pkgs/main::cyrus-sasl-2.1.28-h52b45da~ --> conda-forge::cyrus-sasl-2.1.27-h54b06d7_7
#   libcups               pkgs/main::libcups-2.4.2-h2d74bed_1 --> conda-forge::libcups-2.3.3-h4637d8d_4
#   sqlite                pkgs/main::sqlite-3.45.3-h5eee18b_0 --> conda-forge::sqlite-3.32.3-hcee41ef_1
#   tk                        pkgs/main::tk-8.6.14-h39e8969_0 --> conda-forge::tk-8.6.13-noxft_h4845f30_101
#
#
#
# Downloading and Extracting Packages:
# tensorflow-base-2.16 | 348.6 MB  |                                       |   0%
# libcublas-12.5.3.2   | 240.0 MB  |                                       |   0%
#
# libcufft-11.2.3.61   | 148.6 MB  |                                       |   0%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  |                                       |   0%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  |                                       |   0%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   |                                       |   0%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   |                                       |   0%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   |                                       |   0%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   |                                       |   0%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# mysql-server-8.3.0   | 17.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.5 | 11.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-18.1.8    | 10.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 7.0 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-2.16.2   | 4.9 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 4.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-8.3.0   | 4.3 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-devel-8.3.0    | 1.8 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# tensorflow-base-2.16 | 348.6 MB  |                                       |   0%
# libcublas-12.5.3.2   | 240.0 MB  |                                       |   0%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  |                                       |   0%
#
#
# tensorflow-base-2.16 | 348.6 MB  | 1                                     |   0%
# libcublas-12.5.3.2   | 240.0 MB  | 1                                     |   0%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | 3                                     |   1%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | 4                                     |   1%
#
# tensorflow-base-2.16 | 348.6 MB  | 2                                     |   1%
# libcublas-12.5.3.2   | 240.0 MB  | 3                                     |   1%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #                                     |   3%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | 6                                     |   2%
#
# tensorflow-base-2.16 | 348.6 MB  | 6                                     |   2%
# libcublas-12.5.3.2   | 240.0 MB  | 6                                     |   2%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #9                                    |   5%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #7                                    |   5%
#
# libcufft-11.2.3.61   | 148.6 MB  | #7                                    |   5%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##3                                   |   6%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##5                                   |   7%
# tensorflow-base-2.16 | 348.6 MB  | 7                                     |   2%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##5                                   |   7%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###5                                  |  10%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###3                                  |   9%
# tensorflow-base-2.16 | 348.6 MB  | 9                                     |   3%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###4                                  |   9%
#
# libcufft-11.2.3.61   | 148.6 MB  | ####4                                 |  12%
#
#
# tensorflow-base-2.16 | 348.6 MB  | #2                                    |   3%
# libcublas-12.5.3.2   | 240.0 MB  | #5                                    |   4%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ####5                                 |  12%
#
#
# tensorflow-base-2.16 | 348.6 MB  | #5                                    |   4%
#
# libcufft-11.2.3.61   | 148.6 MB  | #####1                                |  14%
# libcublas-12.5.3.2   | 240.0 MB  | #9                                    |   5%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #####3                                |  14%
#
#
# tensorflow-base-2.16 | 348.6 MB  | #8                                    |   5%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ######1                               |  17%
# libcublas-12.5.3.2   | 240.0 MB  | ##2                                   |   6%
#
# libcufft-11.2.3.61   | 148.6 MB  | #####8                                |  16%
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##2                                   |   6%
# libcublas-12.5.3.2   | 240.0 MB  | ##7                                   |   7%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #######3                              |  20%
#
# libcufft-11.2.3.61   | 148.6 MB  | ######4                               |  17%
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##5                                   |   7%
# libcublas-12.5.3.2   | 240.0 MB  | ###                                   |   8%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ########1                             |  22%
#
# tensorflow-base-2.16 | 348.6 MB  | ##7                                   |   8%
# libcublas-12.5.3.2   | 240.0 MB  | ###4                                  |   9%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ########6                             |  23%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #########                             |  24%
#
# tensorflow-base-2.16 | 348.6 MB  | ###                                   |   8%
# libcublas-12.5.3.2   | 240.0 MB  | ###7                                  |  10%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #########3                            |  25%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #########7                            |  26%
#
# tensorflow-base-2.16 | 348.6 MB  | ###5                                  |   9%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##########8                           |  29%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##########3                           |  28%
# libcublas-12.5.3.2   | 240.0 MB  | ####                                  |  11%
#
# tensorflow-base-2.16 | 348.6 MB  | ###7                                  |  10%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###########                           |  30%
# libcublas-12.5.3.2   | 240.0 MB  | ####3                                 |  12%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####                                  |  11%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ############1                         |  33%
#
# libcufft-11.2.3.61   | 148.6 MB  | #########5                            |  26%
# libcublas-12.5.3.2   | 240.0 MB  | ####8                                 |  13%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####3                                 |  12%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #############                         |  35%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##########3                           |  28%
# libcublas-12.5.3.2   | 240.0 MB  | #####2                                |  14%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####6                                 |  12%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #############9                        |  38%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##############7                       |  40%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##########9                           |  30%
# tensorflow-base-2.16 | 348.6 MB  | ####8                                 |  13%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##############6                       |  40%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###########5                          |  31%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###############6                      |  42%
# tensorflow-base-2.16 | 348.6 MB  | #####1                                |  14%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###############6                      |  42%
#
# libcufft-11.2.3.61   | 148.6 MB  | ############2                         |  33%
# libcublas-12.5.3.2   | 240.0 MB  | ######3                               |  17%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #####4                                |  15%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ################4                     |  45%
#
# libcufft-11.2.3.61   | 148.6 MB  | ############8                         |  35%
# libcublas-12.5.3.2   | 240.0 MB  | ######7                               |  18%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #####7                                |  15%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #################4                    |  47%
#
# libcufft-11.2.3.61   | 148.6 MB  | #############3                        |  36%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##################3                   |  50%
# tensorflow-base-2.16 | 348.6 MB  | #####9                                |  16%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##################2                   |  49%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##############                        |  38%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###################3                  |  52%
# tensorflow-base-2.16 | 348.6 MB  | ######2                               |  17%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###################                   |  52%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##############6                       |  40%
# libcublas-12.5.3.2   | 240.0 MB  | #######8                              |  21%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ####################1                 |  55%
#
#
# tensorflow-base-2.16 | 348.6 MB  | ######5                               |  18%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###############4                      |  42%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ####################6                 |  56%
# libcublas-12.5.3.2   | 240.0 MB  | ########2                             |  22%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ######7                               |  18%
#
# libcufft-11.2.3.61   | 148.6 MB  | ################                      |  43%
# libcublas-12.5.3.2   | 240.0 MB  | ########5                             |  23%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #####################9                |  59%
#
#
# tensorflow-base-2.16 | 348.6 MB  | #######                               |  19%
#
# libcufft-11.2.3.61   | 148.6 MB  | ################7                     |  45%
# libcublas-12.5.3.2   | 240.0 MB  | ########8                             |  24%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ######################9               |  62%
#
#
# tensorflow-base-2.16 | 348.6 MB  | #######3                              |  20%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #######################1              |  63%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #######################7              |  64%
#
# tensorflow-base-2.16 | 348.6 MB  | #######5                              |  21%
# libcublas-12.5.3.2   | 240.0 MB  | #########2                            |  25%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##################1                   |  49%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #######################9              |  65%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ########################6             |  67%
# tensorflow-base-2.16 | 348.6 MB  | #######8                              |  21%
# libcublas-12.5.3.2   | 240.0 MB  | #########9                            |  27%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ########################7             |  67%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##################7                   |  51%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ########                              |  22%
# libcublas-12.5.3.2   | 240.0 MB  | ##########3                           |  28%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #########################7            |  70%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###################5                  |  53%
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ########3                             |  23%
#
# libcufft-11.2.3.61   | 148.6 MB  | ####################2                 |  55%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##########################6           |  72%
# tensorflow-base-2.16 | 348.6 MB  | ########5                             |  23%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###########################7          |  75%
#
# libcufft-11.2.3.61   | 148.6 MB  | ####################8                 |  56%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###########################4          |  74%
# tensorflow-base-2.16 | 348.6 MB  | ########8                             |  24%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #############################         |  78%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ############################1         |  76%
#
# libcufft-11.2.3.61   | 148.6 MB  | #####################5                |  58%
# tensorflow-base-2.16 | 348.6 MB  | #########1                            |  25%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #############################9        |  81%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ############################9         |  78%
#
# tensorflow-base-2.16 | 348.6 MB  | #########3                            |  25%
# libcublas-12.5.3.2   | 240.0 MB  | ###########8                          |  32%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #############################8        |  81%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##############################9       |  84%
#
# tensorflow-base-2.16 | 348.6 MB  | #########5                            |  26%
# libcublas-12.5.3.2   | 240.0 MB  | ############1                         |  33%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###############################8      |  86%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##############################5       |  83%
#
# tensorflow-base-2.16 | 348.6 MB  | #########7                            |  26%
# libcublas-12.5.3.2   | 240.0 MB  | ############6                         |  34%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ################################7     |  88%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ###############################3      |  85%
# tensorflow-base-2.16 | 348.6 MB  | ##########                            |  27%
# libcublas-12.5.3.2   | 240.0 MB  | #############                         |  35%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | #################################6    |  91%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ################################1     |  87%
#
# tensorflow-base-2.16 | 348.6 MB  | ##########3                           |  28%
# libcublas-12.5.3.2   | 240.0 MB  | #############3                        |  36%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##################################4   |  93%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ################################9     |  89%
#
# tensorflow-base-2.16 | 348.6 MB  | ##########6                           |  29%
# libcublas-12.5.3.2   | 240.0 MB  | #############7                        |  37%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | #################################8    |  92%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ###################################2  |  95%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##########################1           |  71%
# tensorflow-base-2.16 | 348.6 MB  | ##########8                           |  29%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##################################6   |  94%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ####################################3 |  98%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##########################8           |  72%
# libcublas-12.5.3.2   | 240.0 MB  | ##############4                       |  39%
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###########1                          |  30%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###########################6          |  75%
# libcublas-12.5.3.2   | 240.0 MB  | ###############                       |  41%
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###########5                          |  31%
#
# libcufft-11.2.3.61   | 148.6 MB  | ############################3         |  77%
# tensorflow-base-2.16 | 348.6 MB  | ###########9                          |  32%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   |                                       |   0%
#
# libcufft-11.2.3.61   | 148.6 MB  | #############################3        |  79%
# libcublas-12.5.3.2   | 240.0 MB  | ################1                     |  44%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ############2                         |  33%
# libcublas-12.5.3.2   | 240.0 MB  | ################5                     |  45%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##############################1       |  81%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #9                                    |   5%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ############7                         |  34%
# libcublas-12.5.3.2   | 240.0 MB  | ################9                     |  46%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | 3                                     |   1%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##############################7       |  83%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #############                         |  35%
# libcublas-12.5.3.2   | 240.0 MB  | #################5                    |  47%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##7                                   |   8%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ####3                                 |  12%
#
# tensorflow-base-2.16 | 348.6 MB  | #############3                        |  36%
# libcublas-12.5.3.2   | 240.0 MB  | #################9                    |  49%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #####2                                |  14%
#
# libcufft-11.2.3.61   | 148.6 MB  | ################################3     |  87%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #############5                        |  37%
# libcublas-12.5.3.2   | 240.0 MB  | ##################4                   |  50%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #####8                                |  16%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ######4                               |  17%
#
# tensorflow-base-2.16 | 348.6 MB  | #############8                        |  37%
# libcublas-12.5.3.2   | 240.0 MB  | ##################9                   |  51%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #######3                              |  20%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #######1                              |  19%
#
# tensorflow-base-2.16 | 348.6 MB  | ##############1                       |  38%
#
#
#
# nccl-2.22.3.1        | 107.3 MB  | ##################################### | 100%
# libcublas-12.5.3.2   | 240.0 MB  | ###################3                  |  52%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ########3                             |  23%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########6                             |  23%
#
# tensorflow-base-2.16 | 348.6 MB  | ##############4                       |  39%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #########8                            |  27%
# libcublas-12.5.3.2   | 240.0 MB  | ###################8                  |  54%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##################################7   |  94%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##############6                       |  40%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ###########                           |  30%
# libcublas-12.5.3.2   | 240.0 MB  | ####################2                 |  55%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###################################3  |  96%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###############                       |  41%
#
#
# libcusparse-12.5.1.3 | 119.1 MB  | ##################################### | 100%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ############3                         |  33%
# libcublas-12.5.3.2   | 240.0 MB  | ####################6                 |  56%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###############2                      |  41%
#
# libcufft-11.2.3.61   | 148.6 MB  | ###################################9  |  97%
# libcublas-12.5.3.2   | 240.0 MB  | #####################1                |  57%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #############5                        |  37%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###############5                      |  42%
#
# libcufft-11.2.3.61   | 148.6 MB  | ####################################4 |  99%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ##############8                       |  40%
# libcublas-12.5.3.2   | 240.0 MB  | #####################5                |  58%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###############8                      |  43%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ################5                     |  45%
# libcublas-12.5.3.2   | 240.0 MB  | ######################                |  60%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ################2                     |  44%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ##################                    |  49%
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ################5                     |  45%
# libcublas-12.5.3.2   | 240.0 MB  | ######################5               |  61%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ###################4                  |  52%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ################8                     |  45%
# libcublas-12.5.3.2   | 240.0 MB  | ######################8               |  62%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ######################3               |  60%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | 7                                     |   2%
# tensorflow-base-2.16 | 348.6 MB  | #################2                    |  47%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ########################1             |  65%
# libcublas-12.5.3.2   | 240.0 MB  | #######################2              |  63%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##7                                   |   8%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #####################9                |  59%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #########################7            |  70%
# libcublas-12.5.3.2   | 240.0 MB  | #######################5              |  64%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #################5                    |  47%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | #######################6              |  64%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ###########################5          |  75%
# libcublas-12.5.3.2   | 240.0 MB  | #######################9              |  65%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #################8                    |  48%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ########################9             |  67%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | #############################2        |  79%
# libcublas-12.5.3.2   | 240.0 MB  | ########################3             |  66%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##################                    |  49%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ########6                             |  23%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##############################8       |  83%
# libcublas-12.5.3.2   | 240.0 MB  | ########################7             |  67%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ###########7                          |  32%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##################3                   |  50%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ################################6     |  88%
# libcublas-12.5.3.2   | 240.0 MB  | #########################             |  68%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | #############8                        |  37%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##################7                   |  51%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##################################### | 100%
#
# libcufft-11.2.3.61   | 148.6 MB  | ##################################### | 100%
# libcublas-12.5.3.2   | 240.0 MB  | #########################3            |  69%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##################################2   |  93%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###################                   |  51%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ###############8                      |  43%
# libcublas-12.5.3.2   | 240.0 MB  | #########################6            |  69%
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ####################################  |  97%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | #################6                    |  48%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###################2                  |  52%
# libcublas-12.5.3.2   | 240.0 MB  | ##########################2           |  71%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ####################7                 |  56%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###################7                  |  53%
# libcublas-12.5.3.2   | 240.0 MB  | ##########################6           |  72%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | #######################               |  62%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ###################################1  |  95%
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####################                  |  54%
# libcublas-12.5.3.2   | 240.0 MB  | ##########################9           |  73%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | 8                                     |   2%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####################3                 |  55%
#
#
#
#
# libcusolver-11.6.3.8 | 79.3 MB   | ####################################5 |  99%
# libcublas-12.5.3.2   | 240.0 MB  | ###########################4          |  74%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ###3                                  |   9%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####################7                 |  56%
# libcublas-12.5.3.2   | 240.0 MB  | ############################          |  76%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##############################7       |  83%
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #####################                 |  57%
# libcublas-12.5.3.2   | 240.0 MB  | ############################5         |  77%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | #######9                              |  22%
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #####################4                |  58%
# libcublas-12.5.3.2   | 240.0 MB  | ############################9         |  78%
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #####################9                |  59%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   |                                       |   0%
# libcublas-12.5.3.2   | 240.0 MB  | #############################6        |  80%
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ######################3               |  60%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | #8                                    |   5%
# libcublas-12.5.3.2   | 240.0 MB  | ##############################1       |  81%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ##############8                       |  40%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ######################6               |  61%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ####8                                 |  13%
# libcublas-12.5.3.2   | 240.0 MB  | ##############################7       |  83%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ################8                     |  46%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ########2                             |  22%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #######################               |  62%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ##################7                   |  51%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ######6                               |  18%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ##########7                           |  29%
# tensorflow-base-2.16 | 348.6 MB  | #######################3              |  63%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | #####################1                |  57%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | #########5                            |  26%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ############9                         |  35%
# tensorflow-base-2.16 | 348.6 MB  | #######################7              |  64%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ###############2                      |  41%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ########################              |  65%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ################3                     |  44%
# tensorflow-base-2.16 | 348.6 MB  | ########################              |  65%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ##########################1           |  71%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ##################8                   |  51%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ##################7                   |  51%
# tensorflow-base-2.16 | 348.6 MB  | ########################3             |  66%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ############################1         |  76%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | #####################7                |  59%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | #####################9                |  59%
# tensorflow-base-2.16 | 348.6 MB  | ########################6             |  67%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ##############################4       |  82%
#
#
#
#
#
#
#
#
# libllvm18-18.1.8     | 36.5 MB   | ########################3             |  66%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ##########################4           |  72%
# libcublas-12.5.3.2   | 240.0 MB  | #################################2    |  90%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ################################6     |  88%
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ########################9             |  67%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ##############################        |  81%
# libcublas-12.5.3.2   | 240.0 MB  | #################################6    |  91%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ###################################6  |  96%
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #########################1            |  68%
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.5 | 22.7 MB   | ##################################2   |  92%
# libcublas-12.5.3.2   | 240.0 MB  | ##################################    |  92%
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #########################5            |  69%
# libcublas-12.5.3.2   | 240.0 MB  | ##################################8   |  94%
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #########################8            |  70%
# tensorflow-base-2.16 | 348.6 MB  | ##########################1           |  71%
# libcublas-12.5.3.2   | 240.0 MB  | ####################################3 |  98%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ####7                                 |  13%
#
#
#
#
#
#
#
#
#
#
#
# mysql-server-8.3.0   | 17.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | #########5                            |  26%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##################################### | 100%
#
#
#
#
#
#
# pillow-10.4.0        | 40.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# mysql-server-8.3.0   | 17.2 MB   | ###9                                  |  11%
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##########################4           |  71%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   | #####9                                |  16%
# libcublas-12.5.3.2   | 240.0 MB  | ####################################9 | 100%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ##############                        |  38%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   | #############9                        |  38%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ##################3                   |  49%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##########################9           |  73%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   | ##########################6           |  72%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ########################1             |  65%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ###########################2          |  74%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   | ###################################7  |  97%
#
#
#
#
#
#
#
#
#
#
#
# mysql-server-8.3.0   | 17.2 MB   | #############################5        |  80%
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ############################4         |  77%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.5 | 11.2 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-18.1.8    | 10.5 MB   |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 7.0 MB    |                                       |   0%
#
#
#
#
#
#
#
# libcurand-10.3.6.82  | 39.8 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ############################8         |  78%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.5 | 11.2 MB   | #####8                                |  16%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-18.1.8    | 10.5 MB   | ####2                                 |  12%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 7.0 MB    | ##########6                           |  29%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #############################2        |  79%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-18.1.8    | 10.5 MB   | ################4                     |  44%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 7.0 MB    | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #############################6        |  80%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##############################2       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-2.16.2   | 4.9 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##############################9       |  84%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 4.5 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.5.82 | 15.9 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-2.16.2   | 4.9 MB    | ##############6                       |  40%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-8.3.0   | 4.3 MB    | ####6                                 |  13%
# tensorflow-base-2.16 | 348.6 MB  | ###############################4      |  85%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | 1                                     |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-devel-8.3.0    | 1.8 MB    | 3                                     |   1%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ################################4     |  88%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | #########################1            |  68%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | #################################     |  89%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ##################################4   |  93% [A
#
#
#
#
#
#
#
#
#
#
#
# mysql-server-8.3.0   | 17.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####################################1 |  98%
#
#
#
#
#
#
#
#
# tensorflow-base-2.16 | 348.6 MB  | ####################################8 | 100%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.5.82   | 18.1 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvvm-tools-12.5 | 11.2 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libgrpc-1.62.2       | 7.0 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-2.16.2   | 4.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-2.16.2   | 4.9 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang13-18.1.8    | 10.5 MB   | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# tensorboard-data-ser | 4.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# font-ttf-ubuntu-0.83 | 1.5 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-devel-8.3.0    | 1.8 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-8.3.0   | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# mysql-client-8.3.0   | 4.3 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# hdf5-1.14.3          | 3.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
# qt-main-5.15.8       | 57.6 MB   | ##################################### | 100%
# tensorflow-base-2.16 | 348.6 MB  | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: / By downloading and using the cuDNN conda packages, you accept the terms and conditions of the NVIDIA cuDNN EULA -
#   https://docs.nvidia.com/deeplearning/cudnn/sla/index.html
#
# done
#
# Note: you may need to restart the kernel to use updated packages.
